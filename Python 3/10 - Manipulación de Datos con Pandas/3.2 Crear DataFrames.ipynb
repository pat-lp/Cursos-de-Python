# %% [markdown]
# #**3.2 Crear DataFrames**

# %%
import pandas as pd

# %%
#SE CREA UN DATAFRAME A PARTIR DE UN DICCIONARIO

data = {
    'Provincia': ['Buenos Aires', 'Neuquén', 'Catamarca'],
    'Población': [300000, 200000, 100000],
}

df = pd.DataFrame(data)
df
# Out:
#       Provincia  Población
# 0  Buenos Aires     300000
# 1       Neuquén     200000
# 2     Catamarca     100000

# %%
#SABER EL CONTENIDO DE LAS COLUMNAS

print('PRIMER MANERA DE IMPRIMIR EL CONTENIDO DE UNA COLUMNA\n{}\n'.format(df['Población']))
print(f'SEGUNDA MANERA DE IMPRIMIR EL CONTENIDO DE UNA COLUMNA \n{df.Población}\n')
# Out:
# PRIMER MANERA DE IMPRIMIR EL CONTENIDO DE UNA COLUMNA
# 0    300000
# 1    200000
# 2    100000
# Name: Población, dtype: int64
#
# SEGUNDA MANERA DE IMPRIMIR EL CONTENIDO DE UNA COLUMNA
# 0    300000
# 1    200000
# 2    100000
# Name: Población, dtype: int64

# %%
#SABER EL TIPO DE DATO DE CADA COLUMNA

print(df.dtypes)
# Out:
# Provincia    object
# Población     int64
# dtype: object
